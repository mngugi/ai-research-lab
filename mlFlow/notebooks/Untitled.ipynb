# %%
# %run test.ipynb
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /usr/lib/python3.14/site-packages/nbformat/reader.py:19, in parse_json(s, **kwargs)
#      18 try:
# ---> 19     nb_dict = json.loads(s, **kwargs)
#      20 except ValueError as e:
#
# File /usr/lib64/python3.14/json/__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File /usr/lib64/python3.14/json/decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# ...
